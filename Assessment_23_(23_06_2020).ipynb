# %% [markdown]
# ##CSE-221710313011-D.Manasa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data=pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1=data.copy()
data1
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df=pd.DataFrame(data1)
df['Age'].fillna(df['Age'].mean(), inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=pd.DataFrame(data1)

df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df['Cabin'].fillna(df['Cabin'].mode()[0], inplace=True)
df

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.Sex=le.fit_transform(df.Sex)
df.Name=le.fit_transform(df.Name)
df.Ticket=le.fit_transform(df.Ticket)
df.Cabin=le.fit_transform(df.Cabin)
df.Embarked=le.fit_transform(df.Embarked)
df
# Out:
#      PassengerId  Survived  Pclass  Name  ...  Ticket     Fare  Cabin  Embarked
# 0              1         0       3   108  ...     523   7.2500     47         2
# 1              2         1       1   190  ...     596  71.2833     81         0
# 2              3         1       3   353  ...     669   7.9250     47         2
# 3              4         1       1   272  ...      49  53.1000     55         2
# 4              5         0       3    15  ...     472   8.0500     47         2
# ..           ...       ...     ...   ...  ...     ...      ...    ...       ...
# 886          887         0       2   548  ...     101  13.0000     47         2
# 887          888         1       1   303  ...      14  30.0000     30         2
# 888          889         0       3   413  ...     675  23.4500     47         2
# 889          890         1       1    81  ...       8  30.0000     60         0
# 890          891         0       3   220  ...     466   7.7500     47         1
#
# ...

# %%
df=data.copy()
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.isna())

# %%
import missingno as msno
msno.matrix(data)

# %%
df.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f6d2f54e0>,
# ...
#       dtype=object)

# %%
plt.boxplot(data.Fare)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6f6cf4fe80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6f6cf05588>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6f6cf0d048>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6f6cf05c88>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6f6cf4fc88>,
#   <matplotlib.lines.Line2D at 0x7f6f6cf05208>]}

# %%
X = df.drop('Survived',axis=1)
X.shape
y=df.iloc[:,0]
y.shape
# Out:
# (891,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.25,random_state=1)#random_state = to select the constant rows

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (668, 11)
# (223, 11)
# (668,)
# (223,)

# %%
X_train
# Out:
#      PassengerId  Pclass  ...  Cabin Embarked
# 35            36       1  ...    NaN        S
# 46            47       3  ...    NaN        Q
# 453          454       1  ...    C92        C
# 291          292       1  ...    B49        C
# 748          749       1  ...    D30        S
# ..           ...     ...  ...    ...      ...
# 715          716       3  ...  F G73        S
# 767          768       3  ...    NaN        Q
# 72            73       2  ...    NaN        S
# 235          236       3  ...    NaN        S
# 37            38       3  ...    NaN        S
#
# [668 rows x 11 columns]

# %%
Y_train
# Out:
# 35      36
# 46      47
# 453    454
# 291    292
# 748    749
#       ...
# 715    716
# 767    768
# 72      73
# 235    236
# 37      38
# Name: PassengerId, Length: 668, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ##DOC LINK:https://docs.google.com/document/d/12RwT29XHcCWI2ns5u0FhhiIETY8EJcmb8FRt0mAKzBY/edit?usp=sharing
