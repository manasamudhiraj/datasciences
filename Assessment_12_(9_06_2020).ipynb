# %% [markdown]
# CSE-221710313011-D.Manasa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv')
df
# Out:
#      Match_SK  match_id  ... Win_Margin Country_id
# 0           0    335987  ...      140.0          1
# 1           1    335988  ...       33.0          1
# 2           2    335989  ...        9.0          1
# 3           3    335990  ...        5.0          1
# 4           4    335991  ...        5.0          1
# ..        ...       ...  ...        ...        ...
# 632       632   1082646  ...       10.0          1
# 633       633   1082647  ...       20.0          1
# 634       634   1082648  ...        7.0          1
# 635       635   1082649  ...        6.0          1
# 636       636   1082650  ...        1.0          1
#
# [637 rows x 17 columns]

# %%
df=pd.read_csv('https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv')
df.set_index(["Venue_Name","ManOfMach"],inplace=True)
df.head()
a=df.loc["Rajiv Gandhi International Stadium, Uppal"]
a
# Out:
#                    Match_SK  match_id  ... Win_Margin Country_id
# ManOfMach                              ...
# V Sehwag                  6    335993  ...        9.0          1
# YK Pathan                 8    335995  ...        3.0          1
# SE Marsh                 17    336004  ...        7.0          1
# R Vinay Kumar            20    336007  ...        5.0          1
# SC Ganguly               32    336019  ...       23.0          1
# DJ Bravo                 42    336029  ...       25.0          1
# SK Raina                 54    336042  ...        7.0          1
# SK Trivedi              176    501204  ...        8.0          1
# DW Steyn                185    501213  ...       33.0          1
# PC Valthaty             189    501217  ...        8.0          1
# SL Malinga              200    501229  ...       37.0          1
# YK Pathan               215    501244  ...       20.0          1
# V Sehwag                219    501248  ...        4.0          1
# MR Marsh                226    501255  ...        6.0          1
# DA Warner               271    548334  ...        9.0          1
# Mandeep Singh           299    548364  ...       25.0          1
# DW Steyn                313    548378  ...        5.0          1
# DW Steyn                316    548381  ...        9.0          1
# A Mishra                324    598005  ...       22.0          1
# GH Vihari               328    598009  ...        NaN          1
# GH Vihari               345    598026  ...        5.0          1
# I Sharma                363    598044  ...        7.0          1
# DJG Sammy               368    598049  ...        6.0          1
# SK Raina                375    598056  ...       77.0          1
# A Mishra                389    598070  ...       23.0          1
# PA Patel                393    598074  ...        5.0          1
# AT Rayudu               433    734006  ...        7.0          1
# WP Saha                 436    734012  ...        6.0          1
# UT Yadav                440    734020  ...        7.0          1
# DA Warner               443    734026  ...        7.0          1
# DA Warner               491    829778  ...       22.0          1
# DA Warner               504    829804  ...        5.0          1
# V Kohli                 508    829812  ...        6.0          1
# MJ McClenaghan          512    829820  ...        9.0          1
# G Gambhir               524    980920  ...        8.0          1
# DA Warner               528    980928  ...        7.0          1
# Mustafizur Rahman       534    980940  ...        5.0          1
# AB Dinda                538    980948  ...       34.0          1
# DA Warner               543    980958  ...       15.0          1
# B Kumar                 550    980972  ...        5.0          1
# CH Morris               558    980988  ...        7.0          1
#
# [41 rows x 15 columns]

# %%
b=a.sort_values('ManOfMach')
b
# Out:
#                    Match_SK  match_id  ... Win_Margin Country_id
# ManOfMach                              ...
# A Mishra                324    598005  ...       22.0          1
# A Mishra                389    598070  ...       23.0          1
# AB Dinda                538    980948  ...       34.0          1
# AT Rayudu               433    734006  ...        7.0          1
# B Kumar                 550    980972  ...        5.0          1
# CH Morris               558    980988  ...        7.0          1
# DA Warner               504    829804  ...        5.0          1
# DA Warner               491    829778  ...       22.0          1
# DA Warner               528    980928  ...        7.0          1
# DA Warner               543    980958  ...       15.0          1
# DA Warner               271    548334  ...        9.0          1
# DA Warner               443    734026  ...        7.0          1
# DJ Bravo                 42    336029  ...       25.0          1
# DJG Sammy               368    598049  ...        6.0          1
# DW Steyn                185    501213  ...       33.0          1
# DW Steyn                316    548381  ...        9.0          1
# DW Steyn                313    548378  ...        5.0          1
# G Gambhir               524    980920  ...        8.0          1
# GH Vihari               328    598009  ...        NaN          1
# GH Vihari               345    598026  ...        5.0          1
# I Sharma                363    598044  ...        7.0          1
# MJ McClenaghan          512    829820  ...        9.0          1
# MR Marsh                226    501255  ...        6.0          1
# Mandeep Singh           299    548364  ...       25.0          1
# Mustafizur Rahman       534    980940  ...        5.0          1
# PA Patel                393    598074  ...        5.0          1
# PC Valthaty             189    501217  ...        8.0          1
# R Vinay Kumar            20    336007  ...        5.0          1
# SC Ganguly               32    336019  ...       23.0          1
# SE Marsh                 17    336004  ...        7.0          1
# SK Raina                375    598056  ...       77.0          1
# SK Raina                 54    336042  ...        7.0          1
# SK Trivedi              176    501204  ...        8.0          1
# SL Malinga              200    501229  ...       37.0          1
# UT Yadav                440    734020  ...        7.0          1
# V Kohli                 508    829812  ...        6.0          1
# V Sehwag                219    501248  ...        4.0          1
# V Sehwag                  6    335993  ...        9.0          1
# WP Saha                 436    734012  ...        6.0          1
# YK Pathan               215    501244  ...       20.0          1
# YK Pathan                 8    335995  ...        3.0          1
#
# [41 rows x 15 columns]

# %% [markdown]
# ##Question 1:

# %%
# Print ManOfMach count of each player in Hyderabad stadium

e = b.pivot_table(index=['ManOfMach'],aggfunc='size')
print(e)
# Out:
# ManOfMach
# A Mishra             2
# AB Dinda             1
# AT Rayudu            1
# B Kumar              1
# CH Morris            1
# DA Warner            6
# DJ Bravo             1
# DJG Sammy            1
# DW Steyn             3
# G Gambhir            1
# GH Vihari            2
# I Sharma             1
# MJ McClenaghan       1
# MR Marsh             1
# Mandeep Singh        1
# Mustafizur Rahman    1
# PA Patel             1
# PC Valthaty          1
# R Vinay Kumar        1
# SC Ganguly           1
# SE Marsh             1
# SK Raina             2
# SK Trivedi           1
# SL Malinga           1
# UT Yadav             1
# V Kohli              1
# V Sehwag             2
# WP Saha              1
# YK Pathan            2
# dtype: int64

# %%
def fun(st):
  t= df['Country_Name'].str.contains(st).value_counts()
  p.append(t[1])
p=[]
fun("India")
fun("U.A.E")
fun("South Africa")
p
# Out:
# [560, 20, 57]

# %% [markdown]
# ##Question 2:

# %%
# Plot a pie chart for the country_name column

pd = ["India","U.A.E","South Africa"]
plt.pie(p,labels=pd,startangle=45,explode=[0.1,0,0],colors=["blue","red","green"],autopct="%0.1f%%")
plt.show()
